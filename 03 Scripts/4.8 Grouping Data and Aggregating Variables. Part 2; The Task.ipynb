# %% [markdown]
# # In this Notebook:
#
# 1. Importing libraries
# 2. Importing data
# 3. Find the order mean for each department
# 4. Create a loyal customer flag
# 5. Check the spending habits of different customers based on their loyalty category
# 6. Create a spending flag for each customer
# 7. Create a frequency flag for each customer
# 8. Exporting data

# %% [markdown]
# # 1. Importing libraries

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Importing data

# %%
#Creating path to Instacart Folder
path = r"/Users/katerinapilota/Desktop/Desktop - Pilot's Mac mini/dataimmersion/python/ 02:03:21 Instacart Basket Analysis"

# %%
#importing data
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'final_combined_2'))

# %% [markdown]
# # 3. Finding the aggregated order mean for each department

# %%
#using agg() to find the mean by each department (groupby)
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# # 4. Create a loyal customer flag using transform() and loc()

# %%
#using transform to create a new column with each customer's max order
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#using loc() to create a loyalty flag in a new column
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#checking frequency of loyalty_flag column
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# # 5. Check the spending habits of different customers based on their loyalty category

# %%
#check head of df with new columns
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_days_of_the_week  \
# 0   2539329        1             1                        2
# 1   2398795        1             2                        3
# 2    473747        1             3                        3
# 3   2254736        1             4                        4
# 4    431534        1             5                        4
#
#    time_of_order_24hr_time  days_since_prior_order  product_id  \
# 0                        8                     0.0         196
# 1                        7                    15.0         196
# 2                       12                    21.0         196
# 3                        7                    29.0         196
# 4                       15                    28.0         196
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  prices  \
# 0                  1          0         Soda        77              7     9.0
# 1                  1          1         Soda        77              7     9.0
# 2                  1          1         Soda        77              7     9.0
# 3                  1          1         Soda        77              7     9.0
# 4                  1          1         Soda        77              7     9.0
#
#      price_range_loc     Busiest day     Two busiest days busiest_period_day  \
# 0  Mid-range product  Regularly busy       Regularly busy     Average orders
# 1  Mid-range product  Regularly busy  Two least busy days     Average orders
# 2  Mid-range product  Regularly busy  Two least busy days        Most orders
# 3  Mid-range product  Least busy day  Two least busy days     Average orders
# 4  Mid-range product  Least busy day  Two least busy days        Most orders
#
#    max_order  loyalty_flag
# 0         10  New customer
# 1         10  New customer
# 2         10  New customer
# 3         10  New customer
# 4         10  New customer

# %%
#check desciptive statistics for each loyalty category
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'max', 'min']})
# Out:
#                      prices
#                        mean      max  min
# loyalty_flag
# Loyal customer    10.386336  99999.0  1.0
# New customer      13.294670  99999.0  1.0
# Regular customer  12.495717  99999.0  1.0

# %% [markdown]
# From this we can see that new customers actually buy the most expensive products on average, followed by regular customers and then loyal customers

# %% [markdown]
# # 6. Create a spending flag for each customer

# %%
#create a new 'mean_spend' column using transform and groupby
ords_prods_merge['mean_spend'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
#create a spending flag for low spenders using loc()
ords_prods_merge.loc[ords_prods_merge['mean_spend'] < 10, 'spend_flag'] = 'Low spender'

# %%
#create a spending flag for high spenders
ords_prods_merge.loc[ords_prods_merge['mean_spend'] >= 10, 'spend_flag'] = 'High spender'

# %%
#checking the new spending flag
ords_prods_merge['spend_flag'].value_counts()
# Out:
# Low spender     31770742
# High spender      634117
# Name: spend_flag, dtype: int64

# %%
#check head of df
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_days_of_the_week  \
# 0   2539329        1             1                        2
# 1   2398795        1             2                        3
# 2    473747        1             3                        3
# 3   2254736        1             4                        4
# 4    431534        1             5                        4
#
#    time_of_order_24hr_time  days_since_prior_order  product_id  \
# 0                        8                     0.0         196
# 1                        7                    15.0         196
# 2                       12                    21.0         196
# 3                        7                    29.0         196
# 4                       15                    28.0         196
#
#    add_to_cart_order  reordered product_name  ...  department_id  prices  \
# 0                  1          0         Soda  ...              7     9.0
# 1                  1          1         Soda  ...              7     9.0
# 2                  1          1         Soda  ...              7     9.0
# 3                  1          1         Soda  ...              7     9.0
# 4                  1          1         Soda  ...              7     9.0
#
#      price_range_loc     Busiest day     Two busiest days busiest_period_day  \
# 0  Mid-range product  Regularly busy       Regularly busy     Average orders
# 1  Mid-range product  Regularly busy  Two least busy days     Average orders
# 2  Mid-range product  Regularly busy  Two least busy days        Most orders
# 3  Mid-range product  Least busy day  Two least busy days     Average orders
# 4  Mid-range product  Least busy day  Two least busy days        Most orders
#
#   max_order  loyalty_flag mean_spend   spend_flag
# 0        10  New customer   6.367797  Low spender
# 1        10  New customer   6.367797  Low spender
# 2        10  New customer   6.367797  Low spender
# 3        10  New customer   6.367797  Low spender
# 4        10  New customer   6.367797  Low spender
#
# [5 rows x 21 columns]

# %% [markdown]
# # 7. Create a frequency flag for each customer

# %%
#Create a new column for median for 'days_since_prior_order' for each user
ords_prods_merge['median_ordering'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
#create the flag for infrequent customers
ords_prods_merge.loc[ords_prods_merge['median_ordering'] > 20, 'freq_flag'] = 'Non-frequent customer'

# %%
#create a flag for regular customers
ords_prods_merge.loc[(ords_prods_merge['median_ordering'] <= 20) & (ords_prods_merge['median_ordering'] > 10), 'freq_flag'] = 'Regular customer'

# %%
#Create the Flag for frequent customer
ords_prods_merge.loc[ords_prods_merge['median_ordering'] <= 10, 'freq_flag'] = 'Frequent customer'

# %% [markdown]
# # 8. Export Data

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'final_combined_3'))

# %% [markdown]
# End.
