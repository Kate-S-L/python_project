# %% [markdown]
# In this Notebook:
# Combine two csv files using merge
# Exporting combined data as .csv and .pkl files

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
#Creating path to Instacart Folder
path = r"/Users/katerinapilota/Desktop/Desktop - Pilot's Mac mini/dataimmersion/python/ 02:03:21 Instacart Basket Analysis"

# %%
#Importing order_products_prior.csv
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products__prior.csv'), index_col = False)

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
#Importing orders_checked.csv
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'), index_col = False)

# %%
df_ords.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  \
# 0           0             0   2539329        1             1
# 1           1             1   2398795        1             2
# 2           2             2    473747        1             3
# 3           3             3   2254736        1             4
# 4           4             4    431534        1             5
#
#    orders_days_of_the_week  time_of_order_24hr_time  days_since_prior_order
# 0                        2                        8                     0.0
# 1                        3                        7                    15.0
# 2                        3                       12                    21.0
# 3                        4                        7                    29.0
# 4                        4                       15                    28.0

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
#merging the two data sets
df_merged_1 = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_1
# Out:
#           Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  \
# 0                  0             0   2539329        1             1
# 1                  0             0   2539329        1             1
# 2                  0             0   2539329        1             1
# 3                  0             0   2539329        1             1
# 4                  0             0   2539329        1             1
# ...              ...           ...       ...      ...           ...
# 32434484     3421081       3421081   2977660   206209            13
# 32434485     3421081       3421081   2977660   206209            13
# 32434486     3421081       3421081   2977660   206209            13
# 32434487     3421081       3421081   2977660   206209            13
# 32434488     3421081       3421081   2977660   206209            13
#
#           orders_days_of_the_week  time_of_order_24hr_time  \
# 0                               2                        8
# 1                               2                        8
# 2                               2                        8
# 3                               2                        8
# 4                               2                        8
# ...                           ...                      ...
# 32434484                        1                       12
# 32434485                        1                       12
# 32434486                        1                       12
# 32434487                        1                       12
# 32434488                        1                       12
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                            0.0         196                  1          0
# 1                            0.0       14084                  2          0
# 2                            0.0       12427                  3          0
# 3                            0.0       26088                  4          0
# 4                            0.0       26405                  5          0
# ...                          ...         ...                ...        ...
# 32434484                     7.0       14197                  5          1
# 32434485                     7.0       38730                  6          0
# 32434486                     7.0       31477                  7          0
# 32434487                     7.0        6567                  8          0
# 32434488                     7.0       22920                  9          0
#
#          _merge
# 0          both
# 1          both
# 2          both
# 3          both
# 4          both
# ...         ...
# 32434484   both
# 32434485   both
# 32434486   both
# 32434487   both
# 32434488   both
#
# [32434489 rows x 12 columns]

# %%
#checking whether the dataframes have full match
df_merged_1.shape
# Out:
# (32434489, 12)

# %%
df_merged_1['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Export data to csv

df_merged_1.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.csv'))

# %%
# Export data to pkl

df_merged_1.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
