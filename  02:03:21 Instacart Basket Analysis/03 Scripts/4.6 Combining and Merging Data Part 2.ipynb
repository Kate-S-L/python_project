# %% [markdown]
# In this NoteBook
# Import Merged Dataset : orders_products_combined.pkl
# Combining two Dataframes
# Exporting as a single dataset

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
#Creating path to Instacart Folder
path = r"/Users/katerinapilota/Desktop/Desktop - Pilot's Mac mini/dataimmersion/python/ 02:03:21 Instacart Basket Analysis"

# %%
#Importing data
#1. Import merged data set : orders_products_combined.pkl
merged_1 = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
merged_1.shape
# Out:
# (32434489, 12)

# %%
merged_1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  \
# 0           0             0   2539329        1             1
# 1           0             0   2539329        1             1
# 2           0             0   2539329        1             1
# 3           0             0   2539329        1             1
# 4           0             0   2539329        1             1
#
#    orders_days_of_the_week  time_of_order_24hr_time  days_since_prior_order  \
# 0                        2                        8                     0.0
# 1                        2                        8                     0.0
# 2                        2                        8                     0.0
# 3                        2                        8                     0.0
# 4                        2                        8                     0.0
#
#    product_id  add_to_cart_order  reordered _merge
# 0         196                  1          0   both
# ...

# %%
#dropping first "merge" indicator column
merged_1.drop(columns = ['_merge'])
# Out:
#           Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  \
# 0                  0             0   2539329        1             1
# 1                  0             0   2539329        1             1
# 2                  0             0   2539329        1             1
# 3                  0             0   2539329        1             1
# 4                  0             0   2539329        1             1
# ...              ...           ...       ...      ...           ...
# 32434484     3421081       3421081   2977660   206209            13
# 32434485     3421081       3421081   2977660   206209            13
# 32434486     3421081       3421081   2977660   206209            13
# 32434487     3421081       3421081   2977660   206209            13
# 32434488     3421081       3421081   2977660   206209            13
#
#           orders_days_of_the_week  time_of_order_24hr_time  \
# 0                               2                        8
# ...

# %%
#importing products_checked.csv
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# 2. Combining Two Dataframes

# %%
merged_2 = merged_1.merge(df_prods, on = 'product_id', indicator = 'True')

# %%
merged_2
# Out:
#           Unnamed: 0_x  Unnamed: 0.1  order_id  user_id  order_number  \
# 0                    0             0   2539329        1             1
# 1                    1             1   2398795        1             2
# 2                    2             2    473747        1             3
# 3                    3             3   2254736        1             4
# 4                    4             4    431534        1             5
# ...                ...           ...       ...      ...           ...
# 32404854       3360493       3360493   1320836   202557            17
# 32404855       3360494       3360494     31526   202557            18
# 32404856       3376038       3376038    758936   203436             1
# 32404857       3376039       3376039   2745165   203436             2
# 32404858       3408036       3408036   3093936   205420             1
#
#           orders_days_of_the_week  time_of_order_24hr_time  \
# 0                               2                        8
# ...

# %%
#3. Exporting the data
merged_2.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'final_combined.pkl'))
